# %% [markdown]
# <a href="https://colab.research.google.com/github/FathimaNazarudeen/s3./blob/main/G.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! /content/drive/MyDrive/autism
# Out:
# /bin/bash: /content/drive/MyDrive/autism: No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from keras import regularizers
from keras.preprocessing.image import ImageDataGenerator
train_datagen=ImageDataGenerator(rescale=1./255)
valid_datagen=ImageDataGenerator(rescale=1./255)

# %%
train_dir="/content/drive/MyDrive/fathima/train"
val_dir="/content/drive/MyDrive/fathima/valid"

# %%
train_data=train_datagen.flow_from_directory(train_dir, target_size=(224, 224), class_mode='binary', batch_size=1,seed=42)
valid_data=valid_datagen.flow_from_directory(val_dir, target_size=(224, 224), class_mode='binary',batch_size=1,seed=42)
# Out:
# Found 2636 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.

# %%
model_1=tf.keras.models.Sequential([
                                    tf.keras.layers.Conv2D(filters=32,
                                                           kernel_size=3,
                                                           activation="relu",
                                                           input_shape=(224,224,3)),
                                    tf.keras.layers.Conv2D(32,3,activation="relu",kernel_regularizer=regularizers.l2(0.0001)),
                                    tf.keras.layers.Dropout(0.5),
                                    tf.keras.layers.MaxPool2D(pool_size=2,
                                                              padding="valid"),
                                    tf.keras.layers.Conv2D(64,3,activation="relu",kernel_regularizer=regularizers.l2(0.0001)),
                                    tf.keras.layers.Conv2D(64,3,activation="relu",kernel_regularizer=regularizers.l2(0.0001)),
                                    tf.keras.layers.MaxPool2D(2),
                                    tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dense(256),
                                    tf.keras.layers.Dropout(0.5),
                                    tf.keras.layers.Dense(1,activation="sigmoid")])

# %%
model_1.compile(loss="binary_crossentropy",optimizer=tf.keras.optimizers.SGD(),metrics=["accuracy"])

# %%
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 220, 220, 32)      9248
#
#  dropout (Dropout)           (None, 220, 220, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 110, 110, 32)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 108, 108, 64)      18496
#
#  conv2d_3 (Conv2D)           (None, 106, 106, 64)      36928
#
#  max_pooling2d_1 (MaxPooling  (None, 53, 53, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 179776)            0
#
#  dense (Dense)               (None, 256)               46022912
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 46,088,737
# Trainable params: 46,088,737
# Non-trainable params: 0
# _________________________________________________________________

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=20)

# %%
model=model_1.fit(train_data,epochs=500,validation_data=valid_data,steps_per_epoch=50,callbacks=[callback])
# Out:
# Epoch 1/500
# 50/50 [==============================] - 53s 874ms/step - loss: 1.2199 - accuracy: 0.5600 - val_loss: 0.7073 - val_accuracy: 0.5000
# Epoch 2/500
# 50/50 [==============================] - 8s 166ms/step - loss: 0.7104 - accuracy: 0.5000 - val_loss: 0.7072 - val_accuracy: 0.5000
# Epoch 3/500
# 50/50 [==============================] - 6s 124ms/step - loss: 0.7084 - accuracy: 0.4600 - val_loss: 0.7075 - val_accuracy: 0.5000
# Epoch 4/500
# 50/50 [==============================] - 6s 118ms/step - loss: 0.7000 - accuracy: 0.6000 - val_loss: 0.7101 - val_accuracy: 0.5000
# Epoch 5/500
# 50/50 [==============================] - 7s 142ms/step - loss: 0.7071 - accuracy: 0.5400 - val_loss: 0.7100 - val_accuracy: 0.5000
# Epoch 6/500
# 50/50 [==============================] - 8s 153ms/step - loss: 0.7161 - accuracy: 0.4600 - val_loss: 0.7077 - val_accuracy: 0.5000
# Epoch 7/500
# 50/50 [==============================] - 8s 149ms/step - loss: 0.7111 - accuracy: 0.4200 - val_loss: 0.7073 - val_accuracy: 0.5000
# Epoch 8/500
# 50/50 [==============================] - 6s 119ms/step - loss: 0.7055 - accuracy: 0.5800 - val_loss: 0.7085 - val_accuracy: 0.5000
# Epoch 9/500
# 50/50 [==============================] - 6s 130ms/step - loss: 0.7095 - accuracy: 0.5200 - val_loss: 0.7082 - val_accuracy: 0.5000
# Epoch 10/500
# 50/50 [==============================] - 6s 120ms/step - loss: 0.7060 - accuracy: 0.5400 - val_loss: 0.7082 - val_accuracy: 0.5000
# Epoch 11/500
# 50/50 [==============================] - 7s 146ms/step - loss: 0.7110 - accuracy: 0.4600 - val_loss: 0.7075 - val_accuracy: 0.5000
# Epoch 12/500
# 50/50 [==============================] - 6s 124ms/step - loss: 0.7108 - accuracy: 0.3600 - val_loss: 0.7072 - val_accuracy: 0.5000
# Epoch 13/500
# 50/50 [==============================] - 6s 119ms/step - loss: 0.7109 - accuracy: 0.4800 - val_loss: 0.7070 - val_accuracy: 0.5000
# Epoch 14/500
# 50/50 [==============================] - 6s 121ms/step - loss: 0.7276 - accuracy: 0.5000 - val_loss: 0.7070 - val_accuracy: 0.5000
# Epoch 15/500
# 50/50 [==============================] - 5s 91ms/step - loss: 0.6975 - accuracy: 0.6000 - val_loss: 0.7100 - val_accuracy: 0.5000
# Epoch 16/500
# 50/50 [==============================] - 7s 136ms/step - loss: 0.7129 - accuracy: 0.5000 - val_loss: 0.7088 - val_accuracy: 0.5000
# Epoch 17/500
# 50/50 [==============================] - 6s 107ms/step - loss: 0.7160 - accuracy: 0.4200 - val_loss: 0.7072 - val_accuracy: 0.5000
# Epoch 18/500
# 50/50 [==============================] - 6s 116ms/step - loss: 0.7089 - accuracy: 0.4200 - val_loss: 0.7071 - val_accuracy: 0.5000
# Epoch 19/500
# 50/50 [==============================] - 4s 88ms/step - loss: 0.7061 - accuracy: 0.5800 - val_loss: 0.7084 - val_accuracy: 0.5000
# Epoch 20/500
# 50/50 [==============================] - 4s 89ms/step - loss: 0.7006 - accuracy: 0.5800 - val_loss: 0.7103 - val_accuracy: 0.5000
# Epoch 21/500
# 50/50 [==============================] - 5s 107ms/step - loss: 0.7039 - accuracy: 0.5400 - val_loss: 0.7102 - val_accuracy: 0.5000

# %%
import matplotlib.pyplot as plt
import keras
from matplotlib import pyplot as plt
plt.plot(model.history['accuracy'])
plt.plot(model.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(model.history['loss'])
plt.plot(model.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')

plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from tensorflow.keras.preprocessing import image

# %%
def predictImage(filename):
  img1=image.load_img(filename,target_size=(224,224))
  plt.imshow(img1)
  Y=image.img_to_array(img1)
  X=np.expand_dims(Y,axis=0)
  val=model_1.predict(X)
  val=str(val)
  print(val)
  #print(val[[0]])
  if val=="[[1. 0.]]":
    plt.xlabel("autism",fontsize=30)
  elif val=="[[0. 1.]]":
    plt.xlabel("not autism",fontsize=30)

# %%
predictImage("/content/drive/MyDrive/autism/Autism/test/non_autistic/005.jpg")
# Out:
# 1/1 [==============================] - 0s 107ms/step
# [[1.8648453e-12]]

# %%
AlexNet = keras.models.Sequential([
    keras.layers.Conv2D(filters=96, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(224,224,3)),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    keras.layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same",kernel_regularizer=regularizers.l2(0.0001)),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same",kernel_regularizer=regularizers.l2(0.0001)),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same",kernel_regularizer=regularizers.l2(0.0001)),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same",kernel_regularizer=regularizers.l2(0.0001)),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    keras.layers.Flatten(),
    keras.layers.Dense(4096, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(4096, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation='sigmoid')
])

# %%
AlexNet.compile(loss='binary_crossentropy', optimizer=tf.optimizers.SGD(lr=0.001), metrics=['accuracy'])
AlexNet.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 54, 54, 96)        34944
#
#  batch_normalization (BatchN  (None, 54, 54, 96)       384
#  ormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 96)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 26, 26, 256)       614656
#
#  batch_normalization_1 (Batc  (None, 26, 26, 256)      1024
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 256)      0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 12, 12, 384)       885120
#
#  batch_normalization_2 (Batc  (None, 12, 12, 384)      1536
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 384)       1327488
#
#  batch_normalization_3 (Batc  (None, 12, 12, 384)      1536
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 12, 12, 256)       884992
#
#  batch_normalization_4 (Batc  (None, 12, 12, 256)      1024
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 5, 5, 256)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 6400)              0
#
#  dense_2 (Dense)             (None, 4096)              26218496
#
#  dropout_2 (Dropout)         (None, 4096)              0
#
#  dense_3 (Dense)             (None, 4096)              16781312
#
#  dropout_3 (Dropout)         (None, 4096)              0
#
#  dense_4 (Dense)             (None, 1)                 4097
#
# =================================================================
# Total params: 46,756,609
# Trainable params: 46,753,857
# Non-trainable params: 2,752
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
history_2=AlexNet.fit(train_data,
                      epochs=100,
                      
                      validation_data=valid_data,
                       callbacks=[callback]
                      )
# Out:
# Epoch 1/100
# 2636/2636 [==============================] - 264s 100ms/step - loss: 1.8471 - accuracy: 0.5455 - val_loss: 0.9322 - val_accuracy: 0.5900
# Epoch 2/100
# 2636/2636 [==============================] - 35s 13ms/step - loss: 0.9103 - accuracy: 0.6009 - val_loss: 0.9187 - val_accuracy: 0.6100
# Epoch 3/100
# 2636/2636 [==============================] - 35s 13ms/step - loss: 0.7953 - accuracy: 0.6502 - val_loss: 0.8265 - val_accuracy: 0.5900
# Epoch 4/100
# 2636/2636 [==============================] - 35s 13ms/step - loss: 0.7576 - accuracy: 0.6612 - val_loss: 0.9945 - val_accuracy: 0.5300
# Epoch 5/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 0.7086 - accuracy: 0.6954 - val_loss: 0.7401 - val_accuracy: 0.7100
# Epoch 6/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 0.6849 - accuracy: 0.7068 - val_loss: 0.8243 - val_accuracy: 0.6300
# Epoch 7/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 0.6675 - accuracy: 0.7246 - val_loss: 0.7326 - val_accuracy: 0.6400
# Epoch 8/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 0.6271 - accuracy: 0.7523 - val_loss: 0.7966 - val_accuracy: 0.6500
# Epoch 9/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 0.5898 - accuracy: 0.7675 - val_loss: 0.8190 - val_accuracy: 0.6600
# Epoch 10/100
# 2636/2636 [==============================] - 35s 13ms/step - loss: 0.5608 - accuracy: 0.7967 - val_loss: 0.9172 - val_accuracy: 0.6600
# Epoch 11/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 0.5421 - accuracy: 0.8027 - val_loss: 0.9572 - val_accuracy: 0.6800
# Epoch 12/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 0.5053 - accuracy: 0.8198 - val_loss: 1.2429 - val_accuracy: 0.6000
# Epoch 13/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 0.5048 - accuracy: 0.8202 - val_loss: 0.9137 - val_accuracy: 0.6700
# Epoch 14/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 0.4831 - accuracy: 0.8316 - val_loss: 1.3416 - val_accuracy: 0.5800
# Epoch 15/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 0.4500 - accuracy: 0.8513 - val_loss: 1.1406 - val_accuracy: 0.6400
# Epoch 16/100
# 2636/2636 [==============================] - 35s 13ms/step - loss: 0.4041 - accuracy: 0.8790 - val_loss: 0.9601 - val_accuracy: 0.6800
# Epoch 17/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 0.3941 - accuracy: 0.8813 - val_loss: 1.3927 - val_accuracy: 0.6000
# Epoch 18/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 0.3593 - accuracy: 0.9017 - val_loss: 1.5239 - val_accuracy: 0.6500
# Epoch 19/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 0.3328 - accuracy: 0.9055 - val_loss: 1.1581 - val_accuracy: 0.7000
# Epoch 20/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 0.3100 - accuracy: 0.9188 - val_loss: 1.5253 - val_accuracy: 0.6800
# Epoch 21/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 0.2989 - accuracy: 0.9211 - val_loss: 1.6641 - val_accuracy: 0.6300
# Epoch 22/100
# 2636/2636 [==============================] - 35s 13ms/step - loss: 0.2649 - accuracy: 0.9404 - val_loss: 1.7130 - val_accuracy: 0.6200
# Epoch 23/100
# 2636/2636 [==============================] - 35s 13ms/step - loss: 0.2813 - accuracy: 0.9317 - val_loss: 1.8983 - val_accuracy: 0.6300
# Epoch 24/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 0.2470 - accuracy: 0.9507 - val_loss: 2.4697 - val_accuracy: 0.5800
# Epoch 25/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 0.2230 - accuracy: 0.9590 - val_loss: 1.6950 - val_accuracy: 0.6100

# %%
def predictImage(filename):
  img1=image.load_img(filename,target_size=(224,224))
  plt.imshow(img1)
  Y=image.img_to_array(img1)
  X=np.expand_dims(Y,axis=0)
  val=AlexNet.predict(X)
  val=str(val)
  print(val)
  #print(val[[0]])
  if val=="[[0. 1.]]":
    plt.xlabel("autism",fontsize=30)
  elif val=="[[1. 0.]]":
    plt.xlabel("not autism",fontsize=30)

# %%
predictImage("/content/drive/MyDrive/autism/Autism/test/non_autistic/008.jpg")
# Out:
# 1/1 [==============================] - 0s 124ms/step
# [[0.]]
