# %% [markdown]
# <a href="https://colab.research.google.com/github/FathimaNazarudeen/s3./blob/main/a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! /content/drive/MyDrive/autism
# Out:
# /bin/bash: /content/drive/MyDrive/autism: No such file or directory

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
train_datagen=ImageDataGenerator(rescale=1./255)
valid_datagen=ImageDataGenerator(rescale=1./255)

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Augmentor
#   Downloading Augmentor-0.2.10-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.1)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.10

# %%
import Augmentor
p = Augmentor.Pipeline("/content/drive/MyDrive/fathima/train")
p.flip_left_right(0.5)
p.black_and_white(0.1)
p.rotate(0.3, 10, 10)
p.skew(0.4, 0.5)
p.zoom(probability = 0.2, min_factor = 1.1, max_factor = 1.5)
p.sample(100)
# Out:
# Initialised with 2539 image(s) found.
# Output directory set to /content/drive/MyDrive/fathima/train/output.
# Processing <PIL.Image.Image image mode=RGB size=224x224 at 0x7F4319D3A310>: 100%|██████████| 100/100 [00:01<00:00, 81.56 Samples/s]

# %%
train_dir="/content/drive/MyDrive/fathima/train"
val_dir="/content/drive/MyDrive/fathima/valid"

# %%
train_data=train_datagen.flow_from_directory(train_dir, target_size=(224, 224), class_mode='binary', batch_size=1,seed=42)
valid_data=valid_datagen.flow_from_directory(val_dir, target_size=(224, 224), class_mode='binary',batch_size=1,seed=42)
# Out:
# Found 2639 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.

# %%
model_1=tf.keras.models.Sequential([
                                    tf.keras.layers.Conv2D(filters=10,
                                                           kernel_size=3,
                                                           activation="relu",
                                                           input_shape=(224,224,3)),
                                    tf.keras.layers.Conv2D(10,3,activation="relu"),
                                    tf.keras.layers.MaxPool2D(pool_size=2,
                                                              padding="valid"),
                                    tf.keras.layers.Conv2D(10,3,activation="relu"),
                                    tf.keras.layers.Conv2D(10,3,activation="relu"),
                                    tf.keras.layers.MaxPool2D(2),
                                    tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dense(2,activation="softmax")])

# %%
model_1.compile(loss="sparse_categorical_crossentropy",optimizer=tf.keras.optimizers.Adam(),metrics=["accuracy"])

# %%
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 10)      280
#
#  conv2d_1 (Conv2D)           (None, 220, 220, 10)      910
#
#  max_pooling2d (MaxPooling2D  (None, 110, 110, 10)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 108, 108, 10)      910
#
#  conv2d_3 (Conv2D)           (None, 106, 106, 10)      910
#
#  max_pooling2d_1 (MaxPooling  (None, 53, 53, 10)       0
#  2D)
#
#  flatten (Flatten)           (None, 28090)             0
#
#  dense (Dense)               (None, 2)                 56182
#
# =================================================================
# Total params: 59,192
# Trainable params: 59,192
# Non-trainable params: 0
# _________________________________________________________________

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=20)

# %%
model=model_1.fit(train_data,epochs=100,validation_data=valid_data,steps_per_epoch=50,callbacks=[callback])
# Out:
# Epoch 1/100
# 50/50 [==============================] - 12s 29ms/step - loss: 0.9154 - accuracy: 0.5200 - val_loss: 0.7010 - val_accuracy: 0.5000
# Epoch 2/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.6930 - accuracy: 0.6000 - val_loss: 0.7023 - val_accuracy: 0.5400
# Epoch 3/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.7029 - accuracy: 0.5400 - val_loss: 0.6963 - val_accuracy: 0.5300
# Epoch 4/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.7849 - accuracy: 0.4800 - val_loss: 0.6956 - val_accuracy: 0.4800
# Epoch 5/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.6915 - accuracy: 0.5200 - val_loss: 0.6913 - val_accuracy: 0.4900
# Epoch 6/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.6917 - accuracy: 0.5000 - val_loss: 0.6940 - val_accuracy: 0.5300
# Epoch 7/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.6910 - accuracy: 0.6000 - val_loss: 0.6907 - val_accuracy: 0.5200
# Epoch 8/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.6717 - accuracy: 0.6200 - val_loss: 0.6584 - val_accuracy: 0.6900
# Epoch 9/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.6804 - accuracy: 0.6200 - val_loss: 0.6808 - val_accuracy: 0.6200
# Epoch 10/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.6599 - accuracy: 0.6400 - val_loss: 0.6614 - val_accuracy: 0.6200
# Epoch 11/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.5969 - accuracy: 0.7000 - val_loss: 0.7804 - val_accuracy: 0.5800
# Epoch 12/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.5482 - accuracy: 0.6400 - val_loss: 0.5907 - val_accuracy: 0.7300
# Epoch 13/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.6322 - accuracy: 0.7800 - val_loss: 0.6336 - val_accuracy: 0.7000
# Epoch 14/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.6810 - accuracy: 0.7200 - val_loss: 0.6561 - val_accuracy: 0.6300
# Epoch 15/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.5357 - accuracy: 0.8200 - val_loss: 0.6746 - val_accuracy: 0.6500
# Epoch 16/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.6631 - accuracy: 0.6000 - val_loss: 0.6472 - val_accuracy: 0.6600
# Epoch 17/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.6976 - accuracy: 0.6000 - val_loss: 0.6568 - val_accuracy: 0.6800
# Epoch 18/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.6526 - accuracy: 0.7200 - val_loss: 0.6095 - val_accuracy: 0.7200
# Epoch 19/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.5643 - accuracy: 0.6600 - val_loss: 0.5953 - val_accuracy: 0.7400
# Epoch 20/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.6396 - accuracy: 0.6600 - val_loss: 0.5995 - val_accuracy: 0.7300
# Epoch 21/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.5965 - accuracy: 0.6400 - val_loss: 0.6262 - val_accuracy: 0.7000
# Epoch 22/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.6439 - accuracy: 0.6400 - val_loss: 0.6014 - val_accuracy: 0.7200
# Epoch 23/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.4381 - accuracy: 0.8400 - val_loss: 0.5972 - val_accuracy: 0.7300
# Epoch 24/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.4534 - accuracy: 0.8200 - val_loss: 0.6384 - val_accuracy: 0.7300
# Epoch 25/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.4040 - accuracy: 0.8000 - val_loss: 0.7251 - val_accuracy: 0.7300
# Epoch 26/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.5724 - accuracy: 0.7800 - val_loss: 0.7144 - val_accuracy: 0.6700
# Epoch 27/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.6387 - accuracy: 0.6200 - val_loss: 0.6137 - val_accuracy: 0.7100
# Epoch 28/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.6162 - accuracy: 0.6600 - val_loss: 0.5865 - val_accuracy: 0.7300
# Epoch 29/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.6932 - accuracy: 0.7000 - val_loss: 0.5597 - val_accuracy: 0.7600
# Epoch 30/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.5686 - accuracy: 0.7000 - val_loss: 0.5550 - val_accuracy: 0.7400
# Epoch 31/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.6267 - accuracy: 0.6400 - val_loss: 0.5704 - val_accuracy: 0.7700
# Epoch 32/100
# 50/50 [==============================] - 1s 21ms/step - loss: 0.4368 - accuracy: 0.7800 - val_loss: 0.5613 - val_accuracy: 0.7500
# Epoch 33/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.5396 - accuracy: 0.6600 - val_loss: 0.5851 - val_accuracy: 0.7300
# Epoch 34/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.4677 - accuracy: 0.7800 - val_loss: 0.6390 - val_accuracy: 0.6800
# Epoch 35/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.6608 - accuracy: 0.7200 - val_loss: 0.6578 - val_accuracy: 0.7100
# Epoch 36/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.6549 - accuracy: 0.6600 - val_loss: 0.5707 - val_accuracy: 0.7600
# Epoch 37/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.5986 - accuracy: 0.6200 - val_loss: 0.5589 - val_accuracy: 0.7600
# Epoch 38/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.5502 - accuracy: 0.7600 - val_loss: 0.5660 - val_accuracy: 0.7400
# Epoch 39/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.6369 - accuracy: 0.6400 - val_loss: 0.5516 - val_accuracy: 0.7300
# Epoch 40/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.6015 - accuracy: 0.7600 - val_loss: 0.5789 - val_accuracy: 0.7700
# Epoch 41/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.5185 - accuracy: 0.8000 - val_loss: 0.6021 - val_accuracy: 0.7400
# Epoch 42/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.4372 - accuracy: 0.8400 - val_loss: 0.6057 - val_accuracy: 0.7800
# Epoch 43/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.4988 - accuracy: 0.7200 - val_loss: 0.6653 - val_accuracy: 0.7700
# Epoch 44/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.4969 - accuracy: 0.7200 - val_loss: 0.5748 - val_accuracy: 0.7300
# Epoch 45/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.6272 - accuracy: 0.6800 - val_loss: 0.5803 - val_accuracy: 0.7600
# Epoch 46/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.4911 - accuracy: 0.7200 - val_loss: 0.6167 - val_accuracy: 0.7700
# Epoch 47/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.4385 - accuracy: 0.7800 - val_loss: 0.7113 - val_accuracy: 0.7300
# Epoch 48/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.4731 - accuracy: 0.7600 - val_loss: 0.6530 - val_accuracy: 0.7300
# Epoch 49/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.4036 - accuracy: 0.8400 - val_loss: 0.7508 - val_accuracy: 0.7000
# Epoch 50/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.6333 - accuracy: 0.6600 - val_loss: 0.6673 - val_accuracy: 0.7300
# Epoch 51/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.5504 - accuracy: 0.7200 - val_loss: 0.6097 - val_accuracy: 0.7600
# Epoch 52/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.4433 - accuracy: 0.8000 - val_loss: 0.6553 - val_accuracy: 0.7600
# Epoch 53/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.4787 - accuracy: 0.7800 - val_loss: 0.6588 - val_accuracy: 0.7400
# Epoch 54/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.5665 - accuracy: 0.7400 - val_loss: 0.6217 - val_accuracy: 0.7400
# Epoch 55/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.5758 - accuracy: 0.7600 - val_loss: 0.6343 - val_accuracy: 0.7200
# Epoch 56/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.5183 - accuracy: 0.8200 - val_loss: 0.6479 - val_accuracy: 0.6900
# Epoch 57/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.4692 - accuracy: 0.7800 - val_loss: 0.6398 - val_accuracy: 0.7300
# Epoch 58/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.3943 - accuracy: 0.8200 - val_loss: 0.7497 - val_accuracy: 0.7300
# Epoch 59/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.4425 - accuracy: 0.8000 - val_loss: 0.6622 - val_accuracy: 0.7300
# Epoch 60/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.4632 - accuracy: 0.8400 - val_loss: 0.6306 - val_accuracy: 0.7500
# Epoch 61/100
# 50/50 [==============================] - 1s 14ms/step - loss: 0.4419 - accuracy: 0.8200 - val_loss: 0.6520 - val_accuracy: 0.7000
# Epoch 62/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.4784 - accuracy: 0.7800 - val_loss: 0.6103 - val_accuracy: 0.7600

# %%
import matplotlib.pyplot as plt
import keras
from matplotlib import pyplot as plt
plt.plot(model.history['accuracy'])
plt.plot(model.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(model.history['loss'])
plt.plot(model.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')

plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from tensorflow.keras.preprocessing import image

# %%
def predictImage(filename):
  img1=image.load_img(filename,target_size=(224,224))
  plt.imshow(img1)
  Y=image.img_to_array(img1)
  X=np.expand_dims(Y,axis=0)
  val=model_1.predict(X)
  val=str(val)
  print(val)
  #print(val[[0]])
  if val=="[[1. 0.]]":
    plt.xlabel("autism",fontsize=30)
  elif val=="[[0. 1.]]":
    plt.xlabel("not autism",fontsize=30)

# %%
predictImage("/content/drive/MyDrive/autism/Autism/test/non_autistic/005.jpg")
# Out:
# 1/1 [==============================] - 0s 17ms/step
# [[0. 1.]]

# %%
AlexNet = keras.models.Sequential([
    keras.layers.Conv2D(filters=96, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(224,224,3)),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    keras.layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    keras.layers.Flatten(),
    keras.layers.Dense(4096, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(4096, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(2, activation='softmax')
])

# %%
AlexNet.compile(loss='sparse_categorical_crossentropy', optimizer=tf.optimizers.SGD(lr=0.001), metrics=['accuracy'])
AlexNet.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 54, 54, 96)        34944
#
#  batch_normalization (BatchN  (None, 54, 54, 96)       384
#  ormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 96)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 26, 26, 256)       614656
#
#  batch_normalization_1 (Batc  (None, 26, 26, 256)      1024
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 256)      0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 12, 12, 384)       885120
#
#  batch_normalization_2 (Batc  (None, 12, 12, 384)      1536
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 384)       1327488
#
#  batch_normalization_3 (Batc  (None, 12, 12, 384)      1536
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 12, 12, 256)       884992
#
#  batch_normalization_4 (Batc  (None, 12, 12, 256)      1024
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 5, 5, 256)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 6400)              0
#
#  dense_1 (Dense)             (None, 4096)              26218496
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_2 (Dense)             (None, 4096)              16781312
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_3 (Dense)             (None, 2)                 8194
#
# =================================================================
# Total params: 46,760,706
# Trainable params: 46,757,954
# Non-trainable params: 2,752
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
history_2=AlexNet.fit(train_data,
                      epochs=100,
                      
                      validation_data=valid_data,
                       callbacks=[callback]
                      )
# Out:
# Epoch 1/100
# 2639/2639 [==============================] - 33s 12ms/step - loss: 2.4127 - accuracy: 0.5438 - val_loss: 0.8854 - val_accuracy: 0.5300
# Epoch 2/100
# 2639/2639 [==============================] - 32s 12ms/step - loss: 0.8510 - accuracy: 0.5889 - val_loss: 0.8047 - val_accuracy: 0.6100
# Epoch 3/100
# 2639/2639 [==============================] - 31s 12ms/step - loss: 0.6921 - accuracy: 0.6502 - val_loss: 0.7093 - val_accuracy: 0.6700
# Epoch 4/100
# 2639/2639 [==============================] - 31s 12ms/step - loss: 0.6474 - accuracy: 0.6684 - val_loss: 0.7201 - val_accuracy: 0.6400
# Epoch 5/100
# 2639/2639 [==============================] - 31s 12ms/step - loss: 0.6009 - accuracy: 0.7044 - val_loss: 0.7090 - val_accuracy: 0.6200
# Epoch 6/100
# 2639/2639 [==============================] - 31s 12ms/step - loss: 0.5701 - accuracy: 0.7158 - val_loss: 0.7410 - val_accuracy: 0.6000
# Epoch 7/100
# 2639/2639 [==============================] - 32s 12ms/step - loss: 0.5324 - accuracy: 0.7416 - val_loss: 0.7172 - val_accuracy: 0.6800
# Epoch 8/100
# 2639/2639 [==============================] - 31s 12ms/step - loss: 0.5302 - accuracy: 0.7374 - val_loss: 0.7679 - val_accuracy: 0.5700
# Epoch 9/100
# 2639/2639 [==============================] - 31s 12ms/step - loss: 0.4947 - accuracy: 0.7677 - val_loss: 0.7577 - val_accuracy: 0.6500
# Epoch 10/100
# 2639/2639 [==============================] - 30s 12ms/step - loss: 0.4622 - accuracy: 0.7764 - val_loss: 0.7921 - val_accuracy: 0.6400
# Epoch 11/100
# 2639/2639 [==============================] - 31s 12ms/step - loss: 0.4524 - accuracy: 0.7878 - val_loss: 0.8224 - val_accuracy: 0.6000
# Epoch 12/100
# 2639/2639 [==============================] - 30s 12ms/step - loss: 0.4079 - accuracy: 0.8136 - val_loss: 0.8957 - val_accuracy: 0.6800
# Epoch 13/100
# 2639/2639 [==============================] - 31s 12ms/step - loss: 0.4077 - accuracy: 0.8060 - val_loss: 0.6442 - val_accuracy: 0.7100
# Epoch 14/100
# 2639/2639 [==============================] - 31s 12ms/step - loss: 0.3812 - accuracy: 0.8261 - val_loss: 0.8930 - val_accuracy: 0.6300
# Epoch 15/100
# 2639/2639 [==============================] - 31s 12ms/step - loss: 0.3506 - accuracy: 0.8484 - val_loss: 1.2083 - val_accuracy: 0.5900
# Epoch 16/100
# 2639/2639 [==============================] - 31s 12ms/step - loss: 0.3171 - accuracy: 0.8632 - val_loss: 0.9782 - val_accuracy: 0.6000
# Epoch 17/100
# 2639/2639 [==============================] - 31s 12ms/step - loss: 0.3187 - accuracy: 0.8571 - val_loss: 0.8148 - val_accuracy: 0.7100
# Epoch 18/100
# 2639/2639 [==============================] - 31s 12ms/step - loss: 0.2798 - accuracy: 0.8784 - val_loss: 0.9510 - val_accuracy: 0.6300
# Epoch 19/100
# 2639/2639 [==============================] - 31s 12ms/step - loss: 0.2515 - accuracy: 0.8981 - val_loss: 0.9765 - val_accuracy: 0.6700
# Epoch 20/100
# 2639/2639 [==============================] - 31s 12ms/step - loss: 0.2563 - accuracy: 0.8909 - val_loss: 0.8253 - val_accuracy: 0.6700
# Epoch 21/100
# 2639/2639 [==============================] - 32s 12ms/step - loss: 0.2441 - accuracy: 0.8962 - val_loss: 0.8870 - val_accuracy: 0.7100
# Epoch 22/100
# 2639/2639 [==============================] - 31s 12ms/step - loss: 0.1945 - accuracy: 0.9189 - val_loss: 1.2004 - val_accuracy: 0.6600
# Epoch 23/100
# 2639/2639 [==============================] - 31s 12ms/step - loss: 0.1683 - accuracy: 0.9375 - val_loss: 1.1939 - val_accuracy: 0.6700
# Epoch 24/100
# 2639/2639 [==============================] - 31s 12ms/step - loss: 0.1374 - accuracy: 0.9458 - val_loss: 1.2175 - val_accuracy: 0.6800
# Epoch 25/100
# 2639/2639 [==============================] - 31s 12ms/step - loss: 0.1420 - accuracy: 0.9397 - val_loss: 1.4568 - val_accuracy: 0.6500
# Epoch 26/100
# 2639/2639 [==============================] - 31s 12ms/step - loss: 0.1536 - accuracy: 0.9367 - val_loss: 1.1981 - val_accuracy: 0.6700
# Epoch 27/100
# 2639/2639 [==============================] - 31s 12ms/step - loss: 0.1335 - accuracy: 0.9454 - val_loss: 1.5128 - val_accuracy: 0.5800
# Epoch 28/100
# 2639/2639 [==============================] - 31s 12ms/step - loss: 0.1067 - accuracy: 0.9598 - val_loss: 1.4329 - val_accuracy: 0.6400
# Epoch 29/100
# 2639/2639 [==============================] - 31s 12ms/step - loss: 0.1131 - accuracy: 0.9568 - val_loss: 1.4998 - val_accuracy: 0.6500
# Epoch 30/100
# 2639/2639 [==============================] - 31s 12ms/step - loss: 0.0801 - accuracy: 0.9648 - val_loss: 2.1834 - val_accuracy: 0.5800
# Epoch 31/100
# 2639/2639 [==============================] - 31s 12ms/step - loss: 0.0627 - accuracy: 0.9739 - val_loss: 1.5144 - val_accuracy: 0.6300
# Epoch 32/100
# 2639/2639 [==============================] - 31s 12ms/step - loss: 0.0725 - accuracy: 0.9731 - val_loss: 1.5936 - val_accuracy: 0.6400
# Epoch 33/100
# 2639/2639 [==============================] - 31s 12ms/step - loss: 0.0747 - accuracy: 0.9761 - val_loss: 1.7754 - val_accuracy: 0.6900

# %%
def predictImage(filename):
  img1=image.load_img(filename,target_size=(224,224))
  plt.imshow(img1)
  Y=image.img_to_array(img1)
  X=np.expand_dims(Y,axis=0)
  val=AlexNet.predict(X)
  val=str(val)
  print(val)
  #print(val[[0]])
  if val=="[[0. 1.]]":
    plt.xlabel("autism",fontsize=30)
  elif val=="[[1. 0.]]":
    plt.xlabel("not autism",fontsize=30)

# %%
predictImage("/content/drive/MyDrive/autism/Autism/test/non_autistic/008.jpg")
# Out:
# 1/1 [==============================] - 0s 117ms/step
# [[1. 0.]]
