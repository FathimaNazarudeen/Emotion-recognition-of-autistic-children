# %%
import numpy as np 
import pandas as pd

# %%
import os
import tensorflow as tf
import keras
import cv2
import numpy as np # linear algebra
import pandas as pd

from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model
from tensorflow.keras import layers , models, optimizers

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import *

# %%
img_shape = 48
batch_size = 64
train_data_path = '../input/fer2013/train/'
test_data_path = '../input/fer2013/test/'

# %%
train_gen = ImageDataGenerator(
        rescale= 1 / 255,
        # Data Augmentation
        rotation_range=10,
        zoom_range= 0.2,
        width_shift_range= 0.1,
        height_shift_range= 0.1,
        fill_mode ="nearest"
    
    )

test_gen = ImageDataGenerator(rescale= 1 / 255 )

# %%
train_data = train_gen.flow_from_directory(
    train_data_path,
    class_mode="categorical",
    target_size=(img_shape,img_shape),
    color_mode='rgb', 
    shuffle=True,
    batch_size=batch_size,
    subset='training', 
)


test_data = test_gen.flow_from_directory(
    test_data_path,
    class_mode="categorical",
    target_size=(img_shape,img_shape),
    color_mode="rgb",
    shuffle=False,
    batch_size=batch_size,
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
def Create_CNN_Model():
    
    model = Sequential()
    
    #CNN1
    model.add(Conv2D(32, (3,3), activation='relu', input_shape=(img_shape, img_shape, 3)))
    model.add(BatchNormalization())
    model.add(Conv2D(64,(3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2), padding='same'))
    model.add(Dropout(0.25))
    
    #CNN2
    model.add(Conv2D(64, (3,3), activation='relu', ))
    model.add(BatchNormalization())
    model.add(Conv2D(128,(3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2), padding='same'))
    model.add(Dropout(0.25))
    
    #CNN3
    model.add(Conv2D(128, (3,3), activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(256,(3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2), padding='same'))
    model.add(Dropout(0.25))
    
    
    #Output
    model.add(Flatten())
    
    model.add(Dense(1024, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(512, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(256, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(128, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(64, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(32, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(7,activation='softmax'))
    
    
    return model

# %%
CNN_Model = Create_CNN_Model()

CNN_Model.summary()

CNN_Model.compile(optimizer="adam", loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# 2022-11-22 01:51:01.635344: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 01:51:01.636316: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 01:51:01.931978: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 01:51:01.932835: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 01:51:01.933608: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 01:51:01.934368: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 01:51:01.935684: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-22 01:51:02.191377: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 01:51:02.192237: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 01:51:02.192966: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 01:51:02.193633: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 01:51:02.194319: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 01:51:02.195007: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 01:51:06.580291: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 01:51:06.581231: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 01:51:06.581976: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 01:51:06.582910: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 01:51:06.583674: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 01:51:06.584441: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-11-22 01:51:06.589349: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 01:51:06.590074: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 46, 46, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 46, 46, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 46, 46, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 46, 46, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 23, 23, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 21, 21, 64)        36928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 21, 21, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 21, 21, 128)       73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 21, 21, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 11, 11, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 11, 11, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 9, 9, 128)         147584
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 9, 9, 128)         512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 9, 9, 256)         295168
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 9, 9, 256)         1024
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              6554624
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                2080
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 32)                128
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 7,837,895
# Trainable params: 7,832,519
# Non-trainable params: 5,376
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model

# %%
from tensorflow.keras.models import Model
plot_model(CNN_Model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
steps_per_epoch = train_data.n // train_data.batch_size
validation_steps = test_data.n // test_data.batch_size

# %%
CNN_history = CNN_Model.fit( train_data , 
                            validation_data= test_data ,
                            epochs=50, batch_size= batch_size,
                            
                             steps_per_epoch= steps_per_epoch, 
                            validation_steps=validation_steps
                           )
# Out:
# 2022-11-22 01:51:10.001025: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 2022-11-22 01:51:14.563405: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 448/448 [==============================] - 251s 527ms/step - loss: 2.0430 - accuracy: 0.2177 - val_loss: 1.9574 - val_accuracy: 0.2554
# Epoch 2/50
# 448/448 [==============================] - 78s 174ms/step - loss: 1.7429 - accuracy: 0.3004 - val_loss: 1.5497 - val_accuracy: 0.3890
# Epoch 3/50
# 448/448 [==============================] - 77s 173ms/step - loss: 1.5881 - accuracy: 0.3794 - val_loss: 1.4443 - val_accuracy: 0.4468
# Epoch 4/50
# 448/448 [==============================] - 78s 173ms/step - loss: 1.4744 - accuracy: 0.4311 - val_loss: 1.4019 - val_accuracy: 0.4674
# Epoch 5/50
# 448/448 [==============================] - 79s 176ms/step - loss: 1.3928 - accuracy: 0.4666 - val_loss: 1.3554 - val_accuracy: 0.4711
# Epoch 6/50
# 448/448 [==============================] - 77s 172ms/step - loss: 1.3342 - accuracy: 0.4917 - val_loss: 1.3160 - val_accuracy: 0.4978
# Epoch 7/50
# 448/448 [==============================] - 76s 170ms/step - loss: 1.3017 - accuracy: 0.5085 - val_loss: 1.2621 - val_accuracy: 0.5220
# Epoch 8/50
# 448/448 [==============================] - 77s 172ms/step - loss: 1.2688 - accuracy: 0.5220 - val_loss: 1.2204 - val_accuracy: 0.5398
# Epoch 9/50
# 448/448 [==============================] - 77s 173ms/step - loss: 1.2396 - accuracy: 0.5383 - val_loss: 1.1713 - val_accuracy: 0.5523
# Epoch 10/50
# 448/448 [==============================] - 77s 171ms/step - loss: 1.2123 - accuracy: 0.5507 - val_loss: 1.3091 - val_accuracy: 0.4976
# Epoch 11/50
# 448/448 [==============================] - 76s 169ms/step - loss: 1.1890 - accuracy: 0.5559 - val_loss: 1.1191 - val_accuracy: 0.5759
# Epoch 12/50
# 448/448 [==============================] - 76s 169ms/step - loss: 1.1755 - accuracy: 0.5654 - val_loss: 1.1497 - val_accuracy: 0.5693
# Epoch 13/50
# 448/448 [==============================] - 76s 169ms/step - loss: 1.1520 - accuracy: 0.5734 - val_loss: 1.1344 - val_accuracy: 0.5749
# Epoch 14/50
# 448/448 [==============================] - 76s 169ms/step - loss: 1.1406 - accuracy: 0.5778 - val_loss: 1.0891 - val_accuracy: 0.5921
# Epoch 15/50
# 448/448 [==============================] - 76s 169ms/step - loss: 1.1305 - accuracy: 0.5825 - val_loss: 1.0986 - val_accuracy: 0.5880
# Epoch 16/50
# 448/448 [==============================] - 77s 173ms/step - loss: 1.1168 - accuracy: 0.5871 - val_loss: 1.0749 - val_accuracy: 0.5951
# Epoch 17/50
# 448/448 [==============================] - 76s 170ms/step - loss: 1.0967 - accuracy: 0.5968 - val_loss: 1.0503 - val_accuracy: 0.6091
# Epoch 18/50
# 448/448 [==============================] - 78s 174ms/step - loss: 1.0927 - accuracy: 0.5961 - val_loss: 1.0234 - val_accuracy: 0.6122
# Epoch 19/50
# 448/448 [==============================] - 78s 174ms/step - loss: 1.0700 - accuracy: 0.6100 - val_loss: 1.0137 - val_accuracy: 0.6154
# Epoch 20/50
# 448/448 [==============================] - 76s 170ms/step - loss: 1.0533 - accuracy: 0.6102 - val_loss: 1.0488 - val_accuracy: 0.6016
# Epoch 21/50
# 448/448 [==============================] - 77s 172ms/step - loss: 1.0451 - accuracy: 0.6145 - val_loss: 0.9936 - val_accuracy: 0.6263
# Epoch 22/50
# 448/448 [==============================] - 75s 168ms/step - loss: 1.0326 - accuracy: 0.6231 - val_loss: 0.9875 - val_accuracy: 0.6363
# Epoch 23/50
# 448/448 [==============================] - 76s 169ms/step - loss: 1.0230 - accuracy: 0.6244 - val_loss: 1.0541 - val_accuracy: 0.6052
# Epoch 24/50
# 448/448 [==============================] - 75s 168ms/step - loss: 1.0207 - accuracy: 0.6306 - val_loss: 0.9738 - val_accuracy: 0.6392
# Epoch 25/50
# 448/448 [==============================] - 78s 173ms/step - loss: 0.9988 - accuracy: 0.6345 - val_loss: 0.9785 - val_accuracy: 0.6343
# Epoch 26/50
# 448/448 [==============================] - 76s 169ms/step - loss: 0.9811 - accuracy: 0.6420 - val_loss: 0.9849 - val_accuracy: 0.6349
# Epoch 27/50
# 448/448 [==============================] - 76s 169ms/step - loss: 0.9755 - accuracy: 0.6461 - val_loss: 1.0089 - val_accuracy: 0.6317
# Epoch 28/50
# 448/448 [==============================] - 76s 170ms/step - loss: 0.9710 - accuracy: 0.6457 - val_loss: 1.0093 - val_accuracy: 0.6239
# Epoch 29/50
# 448/448 [==============================] - 76s 170ms/step - loss: 0.9562 - accuracy: 0.6525 - val_loss: 1.0018 - val_accuracy: 0.6317
# Epoch 30/50
# 448/448 [==============================] - 77s 172ms/step - loss: 0.9497 - accuracy: 0.6563 - val_loss: 0.9678 - val_accuracy: 0.6391
# Epoch 31/50
# 448/448 [==============================] - 77s 171ms/step - loss: 0.9466 - accuracy: 0.6586 - val_loss: 1.0442 - val_accuracy: 0.6212
# Epoch 32/50
# 448/448 [==============================] - 76s 170ms/step - loss: 0.9317 - accuracy: 0.6644 - val_loss: 1.0223 - val_accuracy: 0.6229
# Epoch 33/50
# 448/448 [==============================] - 76s 171ms/step - loss: 0.9369 - accuracy: 0.6620 - val_loss: 0.9673 - val_accuracy: 0.6431
# Epoch 34/50
# 448/448 [==============================] - 76s 169ms/step - loss: 0.9328 - accuracy: 0.6623 - val_loss: 1.0208 - val_accuracy: 0.6314
# Epoch 35/50
# 448/448 [==============================] - 76s 169ms/step - loss: 0.9186 - accuracy: 0.6684 - val_loss: 0.9369 - val_accuracy: 0.6554
# Epoch 36/50
# 448/448 [==============================] - 76s 170ms/step - loss: 0.9020 - accuracy: 0.6738 - val_loss: 1.0186 - val_accuracy: 0.6272
# Epoch 37/50
# 448/448 [==============================] - 76s 169ms/step - loss: 0.8996 - accuracy: 0.6757 - val_loss: 0.9376 - val_accuracy: 0.6617
# Epoch 38/50
# 448/448 [==============================] - 76s 169ms/step - loss: 0.8913 - accuracy: 0.6770 - val_loss: 0.9424 - val_accuracy: 0.6519
# Epoch 39/50
# 448/448 [==============================] - 76s 169ms/step - loss: 0.8847 - accuracy: 0.6832 - val_loss: 0.9521 - val_accuracy: 0.6572
# Epoch 40/50
# 448/448 [==============================] - 77s 172ms/step - loss: 0.8822 - accuracy: 0.6827 - val_loss: 1.0476 - val_accuracy: 0.6275
# Epoch 41/50
# 448/448 [==============================] - 76s 171ms/step - loss: 0.8708 - accuracy: 0.6834 - val_loss: 0.9720 - val_accuracy: 0.6434
# Epoch 42/50
# 448/448 [==============================] - 76s 169ms/step - loss: 0.8703 - accuracy: 0.6876 - val_loss: 0.9488 - val_accuracy: 0.6583
# Epoch 43/50
# 448/448 [==============================] - 77s 172ms/step - loss: 0.8591 - accuracy: 0.6918 - val_loss: 0.9267 - val_accuracy: 0.6645
# Epoch 44/50
# 448/448 [==============================] - 77s 173ms/step - loss: 0.8653 - accuracy: 0.6902 - val_loss: 1.0687 - val_accuracy: 0.6150
# Epoch 45/50
# 448/448 [==============================] - 77s 172ms/step - loss: 0.8702 - accuracy: 0.6856 - val_loss: 0.9734 - val_accuracy: 0.6463
# Epoch 46/50
# 448/448 [==============================] - 76s 169ms/step - loss: 0.8473 - accuracy: 0.6959 - val_loss: 0.9323 - val_accuracy: 0.6641
# Epoch 47/50
# 448/448 [==============================] - 76s 170ms/step - loss: 0.8432 - accuracy: 0.6969 - val_loss: 0.9828 - val_accuracy: 0.6582
# Epoch 48/50
# 448/448 [==============================] - 76s 169ms/step - loss: 0.8438 - accuracy: 0.6980 - val_loss: 0.9381 - val_accuracy: 0.6643
# Epoch 49/50
# 448/448 [==============================] - 77s 172ms/step - loss: 0.8296 - accuracy: 0.7034 - val_loss: 0.9789 - val_accuracy: 0.6565
# Epoch 50/50
# 448/448 [==============================] - 78s 174ms/step - loss: 0.8291 - accuracy: 0.7014 - val_loss: 0.9123 - val_accuracy: 0.6724

# %%
CNN_Model.save("kaggle_model.h5")

# %%
CNN_Score = CNN_Model.evaluate(test_data)

print("    Test Loss: {:.5f}".format(CNN_Score[0]))
print("Test Accuracy: {:.2f}%".format(CNN_Score[1] * 100))
# Out:
# 113/113 [==============================] - 11s 95ms/step - loss: 0.9111 - accuracy: 0.6729
#     Test Loss: 0.91114
# Test Accuracy: 67.29%

# %%
def plot_curves(history):

    loss = history.history["loss"]
    val_loss = history.history["val_loss"]

    accuracy = history.history["accuracy"]
    val_accuracy = history.history["val_accuracy"]

    epochs = range(len(history.history["loss"]))

    plt.figure(figsize=(15,5))

    #plot loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, loss, label = "training_loss")
    plt.plot(epochs, val_loss, label = "val_loss")
    plt.title("Loss")
    plt.xlabel("epochs")
    plt.legend()

    #plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, accuracy, label = "training_accuracy")
    plt.plot(epochs, val_accuracy, label = "val_accuracy")
    plt.title("Accuracy")
    plt.xlabel("epochs")
    plt.legend()

# %%
import matplotlib.pyplot as plt
plot_curves(CNN_history)

# %%
CNN_Predictions = CNN_Model.predict(test_data)

# Choosing highest probalbilty class in every prediction 
CNN_Predictions = np.argmax(CNN_Predictions, axis=1)

# %%
test_data.class_indices
# Out:
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
import seaborn as sns 
from sklearn.metrics import confusion_matrix, classification_report

fig, ax= plt.subplots(figsize=(10,5))

cm=confusion_matrix(test_data.labels, CNN_Predictions)

sns.heatmap(cm, annot=True, fmt='g', ax=ax)

ax.set_xlabel('Predicted labels',fontsize=15, fontweight='bold')
ax.set_ylabel('True labels', fontsize=15, fontweight='bold')
ax.set_title('CNN Confusion Matrix', fontsize=20, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'CNN Confusion Matrix')

# %%
# Classification Report

report = classification_report(test_data.classes, CNN_Predictions)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.64      0.60       958
#            1       0.79      0.50      0.61       111
#            2       0.55      0.47      0.50      1024
#            3       0.88      0.85      0.87      1774
#            4       0.64      0.61      0.62      1233
#            5       0.53      0.59      0.56      1247
#            6       0.79      0.82      0.81       831
#
#     accuracy                           0.67      7178
#    macro avg       0.68      0.64      0.65      7178
# weighted avg       0.68      0.67      0.67      7178
