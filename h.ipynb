# %% [markdown]
# <a href="https://colab.research.google.com/github/FathimaNazarudeen/s3./blob/main/h.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! /content/drive/MyDrive/autism
# Out:
# /bin/bash: /content/drive/MyDrive/autism: Is a directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from keras import regularizers
from keras.preprocessing.image import ImageDataGenerator
train_datagen=ImageDataGenerator(rescale=1./255)
valid_datagen=ImageDataGenerator(rescale=1./255)

# %%
train_dir="/content/drive/MyDrive/fathima/train"
val_dir="/content/drive/MyDrive/fathima/valid"

# %%
train_data=train_datagen.flow_from_directory(train_dir, target_size=(224, 224), class_mode='binary', batch_size=1,seed=42)
valid_data=valid_datagen.flow_from_directory(val_dir, target_size=(224, 224), class_mode='binary',batch_size=1,seed=42)
# Out:
# Found 2636 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.

# %%
model_1=tf.keras.models.Sequential([
                                    tf.keras.layers.Conv2D(filters=32,
                                                           kernel_size=3,
                                                           activation="relu",
                                                           input_shape=(224,224,3)),
                                    tf.keras.layers.Conv2D(32,3,activation="relu",kernel_regularizer=regularizers.l1(0.0001)),
                                    tf.keras.layers.MaxPool2D(pool_size=2,),
                                    tf.keras.layers.Dropout(0.5),
                                    tf.keras.layers.MaxPool2D(pool_size=2,
                                                              padding="valid"),
                                    tf.keras.layers.Conv2D(64,3,activation="relu",kernel_regularizer=regularizers.l1(0.0001)),
                                    tf.keras.layers.MaxPool2D(pool_size=2,),
                                    tf.keras.layers.Conv2D(64,3,activation="relu",kernel_regularizer=regularizers.l1(0.0001)),
                                    tf.keras.layers.MaxPool2D(pool_size=2,),
                                    tf.keras.layers.MaxPool2D(2),
                                    tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dense(256),
                                    tf.keras.layers.Dropout(0.5),
                                    tf.keras.layers.Dense(1,activation="sigmoid")])

# %%
model_1.compile(loss="binary_crossentropy",optimizer=tf.keras.optimizers.SGD(),metrics=["accuracy"])

# %%
model_1.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 222, 222, 32)      896
#
#  conv2d_16 (Conv2D)          (None, 220, 220, 32)      9248
#
#  max_pooling2d_12 (MaxPoolin  (None, 110, 110, 32)     0
#  g2D)
#
#  dropout_7 (Dropout)         (None, 110, 110, 32)      0
#
#  max_pooling2d_13 (MaxPoolin  (None, 55, 55, 32)       0
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 53, 53, 64)        18496
#
#  max_pooling2d_14 (MaxPoolin  (None, 26, 26, 64)       0
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, 24, 24, 64)        36928
#
#  max_pooling2d_15 (MaxPoolin  (None, 12, 12, 64)       0
#  g2D)
#
#  max_pooling2d_16 (MaxPoolin  (None, 6, 6, 64)         0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 2304)              0
#
#  dense_7 (Dense)             (None, 256)               590080
#
#  dropout_8 (Dropout)         (None, 256)               0
#
#  dense_8 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 655,905
# Trainable params: 655,905
# Non-trainable params: 0
# _________________________________________________________________

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=20)

# %%
model=model_1.fit(train_data,epochs=500,validation_data=valid_data,steps_per_epoch=50,callbacks=[callback])
# Out:
# Epoch 1/500
# 50/50 [==============================] - 2s 34ms/step - loss: 0.9726 - accuracy: 0.4600 - val_loss: 0.9500 - val_accuracy: 0.5000
# Epoch 2/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.9638 - accuracy: 0.5200 - val_loss: 0.9485 - val_accuracy: 0.5000
# Epoch 3/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.9548 - accuracy: 0.4000 - val_loss: 0.9486 - val_accuracy: 0.5000
# Epoch 4/500
# 50/50 [==============================] - 1s 18ms/step - loss: 0.9518 - accuracy: 0.5000 - val_loss: 0.9491 - val_accuracy: 0.5000
# Epoch 5/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.9549 - accuracy: 0.4800 - val_loss: 0.9472 - val_accuracy: 0.5000
# Epoch 6/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.9370 - accuracy: 0.6000 - val_loss: 0.9534 - val_accuracy: 0.5000
# Epoch 7/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.9513 - accuracy: 0.5200 - val_loss: 0.9505 - val_accuracy: 0.5000
# Epoch 8/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.9486 - accuracy: 0.5200 - val_loss: 0.9473 - val_accuracy: 0.5000
# Epoch 9/500
# 50/50 [==============================] - 1s 16ms/step - loss: 0.9459 - accuracy: 0.5200 - val_loss: 0.9484 - val_accuracy: 0.5000
# Epoch 10/500
# 50/50 [==============================] - 1s 16ms/step - loss: 0.9387 - accuracy: 0.5800 - val_loss: 0.9480 - val_accuracy: 0.5000
# Epoch 11/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.9326 - accuracy: 0.5800 - val_loss: 0.9472 - val_accuracy: 0.5000
# Epoch 12/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.9423 - accuracy: 0.5400 - val_loss: 0.9468 - val_accuracy: 0.5000
# Epoch 13/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.9531 - accuracy: 0.4600 - val_loss: 0.9383 - val_accuracy: 0.5500
# Epoch 14/500
# 50/50 [==============================] - 1s 16ms/step - loss: 0.9494 - accuracy: 0.5200 - val_loss: 0.9386 - val_accuracy: 0.5200
# Epoch 15/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.9577 - accuracy: 0.4600 - val_loss: 0.9402 - val_accuracy: 0.5300
# Epoch 16/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.9366 - accuracy: 0.5800 - val_loss: 0.9395 - val_accuracy: 0.5100
# Epoch 17/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.9421 - accuracy: 0.5800 - val_loss: 0.9371 - val_accuracy: 0.5400
# Epoch 18/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.9378 - accuracy: 0.5000 - val_loss: 0.9373 - val_accuracy: 0.5200
# Epoch 19/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.9275 - accuracy: 0.6400 - val_loss: 0.9365 - val_accuracy: 0.5500
# Epoch 20/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.9138 - accuracy: 0.6600 - val_loss: 0.9280 - val_accuracy: 0.5700
# Epoch 21/500
# 50/50 [==============================] - 1s 16ms/step - loss: 0.9402 - accuracy: 0.5800 - val_loss: 0.9263 - val_accuracy: 0.5900
# Epoch 22/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.8980 - accuracy: 0.6600 - val_loss: 0.9148 - val_accuracy: 0.5600
# Epoch 23/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.9228 - accuracy: 0.6600 - val_loss: 0.9170 - val_accuracy: 0.5900
# Epoch 24/500
# 50/50 [==============================] - 1s 16ms/step - loss: 0.9412 - accuracy: 0.5600 - val_loss: 0.9140 - val_accuracy: 0.6200
# Epoch 25/500
# 50/50 [==============================] - 1s 16ms/step - loss: 0.8974 - accuracy: 0.7600 - val_loss: 0.9110 - val_accuracy: 0.6000
# Epoch 26/500
# 50/50 [==============================] - 1s 16ms/step - loss: 0.9454 - accuracy: 0.4600 - val_loss: 0.9241 - val_accuracy: 0.5400
# Epoch 27/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.8870 - accuracy: 0.7000 - val_loss: 0.9049 - val_accuracy: 0.6500
# Epoch 28/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.9390 - accuracy: 0.5800 - val_loss: 0.9179 - val_accuracy: 0.5700
# Epoch 29/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.8271 - accuracy: 0.6600 - val_loss: 0.8900 - val_accuracy: 0.6500
# Epoch 30/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.8773 - accuracy: 0.6600 - val_loss: 0.8617 - val_accuracy: 0.6600
# Epoch 31/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.8027 - accuracy: 0.6600 - val_loss: 0.8833 - val_accuracy: 0.6200
# Epoch 32/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.9264 - accuracy: 0.5600 - val_loss: 0.9300 - val_accuracy: 0.5500
# Epoch 33/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.9013 - accuracy: 0.6400 - val_loss: 0.8982 - val_accuracy: 0.6300
# Epoch 34/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.8990 - accuracy: 0.6400 - val_loss: 0.8639 - val_accuracy: 0.7200
# Epoch 35/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.8542 - accuracy: 0.7000 - val_loss: 0.8523 - val_accuracy: 0.6600
# Epoch 36/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.8618 - accuracy: 0.6600 - val_loss: 0.8840 - val_accuracy: 0.6600
# Epoch 37/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.8482 - accuracy: 0.7200 - val_loss: 0.8688 - val_accuracy: 0.6600
# Epoch 38/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.8342 - accuracy: 0.7800 - val_loss: 0.8961 - val_accuracy: 0.6100
# Epoch 39/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.8468 - accuracy: 0.7400 - val_loss: 0.8635 - val_accuracy: 0.6900
# Epoch 40/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.8439 - accuracy: 0.6200 - val_loss: 0.8434 - val_accuracy: 0.6700
# Epoch 41/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.9629 - accuracy: 0.6000 - val_loss: 0.8949 - val_accuracy: 0.6400
# Epoch 42/500
# 50/50 [==============================] - 2s 38ms/step - loss: 0.9109 - accuracy: 0.7000 - val_loss: 0.8852 - val_accuracy: 0.6200
# Epoch 43/500
# 50/50 [==============================] - 1s 18ms/step - loss: 0.8245 - accuracy: 0.7200 - val_loss: 0.8963 - val_accuracy: 0.6100
# Epoch 44/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.8573 - accuracy: 0.6600 - val_loss: 0.8707 - val_accuracy: 0.6100
# Epoch 45/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.9181 - accuracy: 0.6400 - val_loss: 0.8851 - val_accuracy: 0.6000
# Epoch 46/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.8899 - accuracy: 0.7200 - val_loss: 0.8745 - val_accuracy: 0.6500
# Epoch 47/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.8464 - accuracy: 0.7400 - val_loss: 0.8668 - val_accuracy: 0.7000
# Epoch 48/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.8998 - accuracy: 0.6800 - val_loss: 0.8791 - val_accuracy: 0.5900
# Epoch 49/500
# 50/50 [==============================] - 1s 16ms/step - loss: 0.8086 - accuracy: 0.7200 - val_loss: 0.8360 - val_accuracy: 0.7000
# Epoch 50/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.9142 - accuracy: 0.7200 - val_loss: 0.9177 - val_accuracy: 0.5700
# Epoch 51/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.9160 - accuracy: 0.5800 - val_loss: 0.9043 - val_accuracy: 0.7100
# Epoch 52/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.8476 - accuracy: 0.6800 - val_loss: 0.8953 - val_accuracy: 0.6700
# Epoch 53/500
# 50/50 [==============================] - 1s 16ms/step - loss: 0.9643 - accuracy: 0.4400 - val_loss: 0.9031 - val_accuracy: 0.7000
# Epoch 54/500
# 50/50 [==============================] - 1s 17ms/step - loss: 0.7776 - accuracy: 0.8000 - val_loss: 0.8462 - val_accuracy: 0.6900

# %%
import matplotlib.pyplot as plt
import keras
from matplotlib import pyplot as plt
plt.plot(model.history['accuracy'])
plt.plot(model.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(model.history['loss'])
plt.plot(model.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')

plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from tensorflow.keras.preprocessing import image

# %%
def predictImage(filename):
  img1=image.load_img(filename,target_size=(224,224))
  plt.imshow(img1)
  Y=image.img_to_array(img1)
  X=np.expand_dims(Y,axis=0)
  val=model_1.predict(X)
  val=str(val)
  print(val)
  #print(val[[0]])
  if val=="[[1. 0.]]":
    plt.xlabel("autism",fontsize=30)
  elif val=="[[0. 1.]]":
    plt.xlabel("not autism",fontsize=30)

# %%
predictImage("/content/drive/MyDrive/autism/Autism/test/non_autistic/005.jpg")
# Out:
# 1/1 [==============================] - 0s 73ms/step
# [[0.99772495]]

# %%
AlexNet = keras.models.Sequential([
    keras.layers.Conv2D(filters=96, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(224,224,3)),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    keras.layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same", kernel_regularizer=regularizers.l1(0.0001)),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same", kernel_regularizer=regularizers.l1(0.0001)),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same", kernel_regularizer=regularizers.l1(0.0001)),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same", kernel_regularizer=regularizers.l1(0.0001)),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    keras.layers.Flatten(),
    keras.layers.Dense(4096, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(4096, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation='sigmoid')
])

# %%
AlexNet.compile(loss='binary_crossentropy', optimizer=tf.optimizers.SGD(lr=0.001), metrics=['accuracy'])
AlexNet.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_39 (Conv2D)          (None, 54, 54, 96)        34944
#
#  batch_normalization_25 (Bat  (None, 54, 54, 96)       384
#  chNormalization)
#
#  max_pooling2d_41 (MaxPoolin  (None, 26, 26, 96)       0
#  g2D)
#
#  conv2d_40 (Conv2D)          (None, 26, 26, 256)       614656
#
#  batch_normalization_26 (Bat  (None, 26, 26, 256)      1024
#  chNormalization)
#
#  max_pooling2d_42 (MaxPoolin  (None, 12, 12, 256)      0
#  g2D)
#
#  conv2d_41 (Conv2D)          (None, 12, 12, 384)       885120
#
#  batch_normalization_27 (Bat  (None, 12, 12, 384)      1536
#  chNormalization)
#
#  conv2d_42 (Conv2D)          (None, 12, 12, 384)       1327488
#
#  batch_normalization_28 (Bat  (None, 12, 12, 384)      1536
#  chNormalization)
#
#  conv2d_43 (Conv2D)          (None, 12, 12, 256)       884992
#
#  batch_normalization_29 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  max_pooling2d_43 (MaxPoolin  (None, 5, 5, 256)        0
#  g2D)
#
#  flatten_8 (Flatten)         (None, 6400)              0
#
#  dense_21 (Dense)            (None, 4096)              26218496
#
#  dropout_17 (Dropout)        (None, 4096)              0
#
#  dense_22 (Dense)            (None, 4096)              16781312
#
#  dropout_18 (Dropout)        (None, 4096)              0
#
#  dense_23 (Dense)            (None, 1)                 4097
#
# =================================================================
# Total params: 46,756,609
# Trainable params: 46,753,857
# Non-trainable params: 2,752
# _________________________________________________________________

# %%
history_2=AlexNet.fit(train_data,
                      epochs=100,
                      
                      validation_data=valid_data,
                       callbacks=[callback]
                      )
# Out:
# Epoch 1/100
# 2636/2636 [==============================] - 36s 13ms/step - loss: 7.3050 - accuracy: 0.5781 - val_loss: 6.4309 - val_accuracy: 0.6100
# Epoch 2/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 6.2894 - accuracy: 0.6032 - val_loss: 6.1918 - val_accuracy: 0.5900
# Epoch 3/100
# 2636/2636 [==============================] - 35s 13ms/step - loss: 6.0754 - accuracy: 0.6529 - val_loss: 6.0043 - val_accuracy: 0.5900
# Epoch 4/100
# 2636/2636 [==============================] - 33s 13ms/step - loss: 5.9208 - accuracy: 0.6806 - val_loss: 5.9687 - val_accuracy: 0.6300
# Epoch 5/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 5.8011 - accuracy: 0.6950 - val_loss: 5.8357 - val_accuracy: 0.5900
# Epoch 6/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 5.6805 - accuracy: 0.7178 - val_loss: 5.8211 - val_accuracy: 0.6100
# Epoch 7/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 5.5668 - accuracy: 0.7299 - val_loss: 5.7600 - val_accuracy: 0.6200
# Epoch 8/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 5.4504 - accuracy: 0.7557 - val_loss: 5.5916 - val_accuracy: 0.6000
# Epoch 9/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 5.3401 - accuracy: 0.7656 - val_loss: 5.5111 - val_accuracy: 0.5900
# Epoch 10/100
# 2636/2636 [==============================] - 33s 13ms/step - loss: 5.2243 - accuracy: 0.7785 - val_loss: 5.6585 - val_accuracy: 0.5900
# Epoch 11/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 5.1066 - accuracy: 0.8012 - val_loss: 5.3689 - val_accuracy: 0.6100
# Epoch 12/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 4.9991 - accuracy: 0.8118 - val_loss: 5.4110 - val_accuracy: 0.6000
# Epoch 13/100
# 2636/2636 [==============================] - 33s 13ms/step - loss: 4.8810 - accuracy: 0.8289 - val_loss: 5.6897 - val_accuracy: 0.5600
# Epoch 14/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 4.7774 - accuracy: 0.8426 - val_loss: 5.2136 - val_accuracy: 0.6400
# Epoch 15/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 4.6767 - accuracy: 0.8547 - val_loss: 5.2137 - val_accuracy: 0.6100
# Epoch 16/100
# 2636/2636 [==============================] - 33s 13ms/step - loss: 4.5480 - accuracy: 0.8767 - val_loss: 5.4572 - val_accuracy: 0.5600
# Epoch 17/100
# 2636/2636 [==============================] - 33s 13ms/step - loss: 4.4656 - accuracy: 0.8756 - val_loss: 5.1283 - val_accuracy: 0.6500
# Epoch 18/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 4.3533 - accuracy: 0.8938 - val_loss: 5.2430 - val_accuracy: 0.5800
# Epoch 19/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 4.2526 - accuracy: 0.9036 - val_loss: 5.3528 - val_accuracy: 0.6500
# Epoch 20/100
# 2636/2636 [==============================] - 33s 13ms/step - loss: 4.1787 - accuracy: 0.9067 - val_loss: 5.2852 - val_accuracy: 0.6000
# Epoch 21/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 4.0750 - accuracy: 0.9181 - val_loss: 4.9858 - val_accuracy: 0.6500
# Epoch 22/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 3.9575 - accuracy: 0.9325 - val_loss: 4.8566 - val_accuracy: 0.6800
# Epoch 23/100
# 2636/2636 [==============================] - 33s 13ms/step - loss: 3.8919 - accuracy: 0.9374 - val_loss: 5.3007 - val_accuracy: 0.5800
# Epoch 24/100
# 2636/2636 [==============================] - 33s 13ms/step - loss: 3.8115 - accuracy: 0.9435 - val_loss: 5.0233 - val_accuracy: 0.6700
# Epoch 25/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 3.7320 - accuracy: 0.9450 - val_loss: 4.8577 - val_accuracy: 0.6900
# Epoch 26/100
# 2636/2636 [==============================] - 33s 13ms/step - loss: 3.6436 - accuracy: 0.9533 - val_loss: 5.0012 - val_accuracy: 0.6400
# Epoch 27/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 3.5356 - accuracy: 0.9651 - val_loss: 5.9059 - val_accuracy: 0.5500
# Epoch 28/100
# 2636/2636 [==============================] - 33s 13ms/step - loss: 3.4908 - accuracy: 0.9590 - val_loss: 5.2403 - val_accuracy: 0.6000
# Epoch 29/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 3.3727 - accuracy: 0.9742 - val_loss: 5.7405 - val_accuracy: 0.5600
# Epoch 30/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 3.3098 - accuracy: 0.9723 - val_loss: 6.0744 - val_accuracy: 0.5400
# Epoch 31/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 3.2665 - accuracy: 0.9632 - val_loss: 5.6655 - val_accuracy: 0.5500
# Epoch 32/100
# 2636/2636 [==============================] - 33s 13ms/step - loss: 3.2053 - accuracy: 0.9613 - val_loss: 5.8141 - val_accuracy: 0.5700
# Epoch 33/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 3.0982 - accuracy: 0.9784 - val_loss: 5.6231 - val_accuracy: 0.5800
# Epoch 34/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 3.1070 - accuracy: 0.9575 - val_loss: 4.8750 - val_accuracy: 0.6200
# Epoch 35/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 2.9721 - accuracy: 0.9753 - val_loss: 5.1089 - val_accuracy: 0.6000
# Epoch 36/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 2.9180 - accuracy: 0.9780 - val_loss: 5.5677 - val_accuracy: 0.5600
# Epoch 37/100
# 2636/2636 [==============================] - 33s 13ms/step - loss: 2.8083 - accuracy: 0.9890 - val_loss: 5.3212 - val_accuracy: 0.6500
# Epoch 38/100
# 2636/2636 [==============================] - 33s 13ms/step - loss: 2.7520 - accuracy: 0.9856 - val_loss: 5.9055 - val_accuracy: 0.5600
# Epoch 39/100
# 2636/2636 [==============================] - 33s 13ms/step - loss: 2.6949 - accuracy: 0.9833 - val_loss: 5.7343 - val_accuracy: 0.5700
# Epoch 40/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 2.6903 - accuracy: 0.9621 - val_loss: 4.8860 - val_accuracy: 0.6300
# Epoch 41/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 2.6502 - accuracy: 0.9632 - val_loss: 4.8236 - val_accuracy: 0.6200
# Epoch 42/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 2.5648 - accuracy: 0.9761 - val_loss: 4.8712 - val_accuracy: 0.6300
# Epoch 43/100
# 2636/2636 [==============================] - 33s 13ms/step - loss: 2.4704 - accuracy: 0.9875 - val_loss: 4.8537 - val_accuracy: 0.6400
# Epoch 44/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 2.3801 - accuracy: 0.9924 - val_loss: 5.1012 - val_accuracy: 0.6200
# Epoch 45/100
# 2636/2636 [==============================] - 34s 13ms/step - loss: 2.2961 - accuracy: 0.9981 - val_loss: 4.4539 - val_accuracy: 0.6600

# %%
def predictImage(filename):
  img1=image.load_img(filename,target_size=(224,224))
  plt.imshow(img1)
  Y=image.img_to_array(img1)
  X=np.expand_dims(Y,axis=0)
  val=AlexNet.predict(X)
  val=str(val)
  print(val)
  #print(val[[0]])
  if val=="[[0. 1.]]":
    plt.xlabel("autism",fontsize=30)
  elif val=="[[1. 0.]]":
    plt.xlabel("not autism",fontsize=30)

# %%
predictImage("/content/drive/MyDrive/autism/Autism/test/non_autistic/008.jpg")
# Out:
# 1/1 [==============================] - 0s 118ms/step
# [[0.]]
