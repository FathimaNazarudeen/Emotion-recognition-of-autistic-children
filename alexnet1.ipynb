# %% [markdown]
# <a href="https://colab.research.google.com/github/FathimaNazarudeen/s3./blob/main/alexnet1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! /content/drive/MyDrive/autism
# Out:
# /bin/bash: /content/drive/MyDrive/autism: Is a directory

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
train_datagen=ImageDataGenerator(rescale=1./255)
valid_datagen=ImageDataGenerator(rescale=1./255)

# %%
train_dir="/content/drive/MyDrive/autism/Autism/train"
val_dir="/content/drive/MyDrive/autism/Autism/valid"

# %%
train_data=train_datagen.flow_from_directory(train_dir, target_size=(224, 224), class_mode='binary', batch_size=1,seed=42)
valid_data=valid_datagen.flow_from_directory(val_dir, target_size=(224, 224), class_mode='binary',batch_size=1,seed=42)
# Out:
# Found 2536 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.

# %%
model_1=tf.keras.models.Sequential([
                                    tf.keras.layers.Conv2D(filters=10,
                                                           kernel_size=3,
                                                           activation="relu",
                                                           input_shape=(224,224,3)),
                                    tf.keras.layers.Conv2D(10,3,activation="relu"),
                                    tf.keras.layers.MaxPool2D(pool_size=2,
                                                              padding="valid"),
                                    tf.keras.layers.Conv2D(10,3,activation="relu"),
                                    tf.keras.layers.Conv2D(10,3,activation="relu"),
                                    tf.keras.layers.MaxPool2D(2),
                                    tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dense(2,activation="softmax")])

# %%
model_1.compile(loss="sparse_categorical_crossentropy",optimizer=tf.keras.optimizers.Adam(),metrics=["accuracy"])

# %%
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 10)      280
#
#  conv2d_1 (Conv2D)           (None, 220, 220, 10)      910
#
#  max_pooling2d (MaxPooling2D  (None, 110, 110, 10)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 108, 108, 10)      910
#
#  conv2d_3 (Conv2D)           (None, 106, 106, 10)      910
#
#  max_pooling2d_1 (MaxPooling  (None, 53, 53, 10)       0
#  2D)
#
#  flatten (Flatten)           (None, 28090)             0
#
#  dense (Dense)               (None, 2)                 56182
#
# =================================================================
# Total params: 59,192
# Trainable params: 59,192
# Non-trainable params: 0
# _________________________________________________________________

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=20)

# %%
model=model_1.fit(train_data,epochs=100,validation_data=valid_data,steps_per_epoch=50,callbacks=[callback])
# Out:
# Epoch 1/100
# 50/50 [==============================] - 53s 888ms/step - loss: 0.7126 - accuracy: 0.4600 - val_loss: 0.6907 - val_accuracy: 0.5000
# Epoch 2/100
# 50/50 [==============================] - 8s 155ms/step - loss: 0.6928 - accuracy: 0.5600 - val_loss: 0.6913 - val_accuracy: 0.5000
# Epoch 3/100
# 50/50 [==============================] - 8s 153ms/step - loss: 0.6955 - accuracy: 0.5600 - val_loss: 0.6928 - val_accuracy: 0.5000
# Epoch 4/100
# 50/50 [==============================] - 8s 170ms/step - loss: 0.6920 - accuracy: 0.5600 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 5/100
# 50/50 [==============================] - 6s 122ms/step - loss: 0.6947 - accuracy: 0.4800 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 6/100
# 50/50 [==============================] - 6s 128ms/step - loss: 0.6949 - accuracy: 0.4600 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 7/100
# 50/50 [==============================] - 9s 178ms/step - loss: 0.6899 - accuracy: 0.6200 - val_loss: 0.6930 - val_accuracy: 0.5000
# Epoch 8/100
# 50/50 [==============================] - 6s 112ms/step - loss: 0.6962 - accuracy: 0.4400 - val_loss: 0.6930 - val_accuracy: 0.5000
# Epoch 9/100
# 50/50 [==============================] - 6s 127ms/step - loss: 0.6935 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch
100
# 50/50 [==============================] - 4s 77ms/step - loss: 0.6900 - accuracy: 0.6000 - val_loss: 0.6948 - val_accuracy: 0.5300

# %%
import matplotlib.pyplot as plt
import keras
from matplotlib import pyplot as plt
plt.plot(model.history['accuracy'])
plt.plot(model.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(model.history['loss'])
plt.plot(model.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')

plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from tensorflow.keras.preprocessing import image

# %%
def predictImage(filename):
  img1=image.load_img(filename,target_size=(224,224))
  plt.imshow(img1)
  Y=image.img_to_array(img1)
  X=np.expand_dims(Y,axis=0)
  val=model_1.predict(X)
  val=str(val)
  print(val)
  #print(val[[0]])
  if val=="[[0. 1.]]":
    plt.xlabel("autism",fontsize=30)
  elif val=="[[1. 0.]]":
    plt.xlabel("not autism",fontsize=30)

# %%
predictImage("/content/drive/MyDrive/autism/Autism/test/autistic/005.jpg")
# Out:
# [[0. 1.]]

# %%
AlexNet = keras.models.Sequential([
    keras.layers.Conv2D(filters=96, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(224,224,3)),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    keras.layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    keras.layers.Flatten(),
    keras.layers.Dense(4096, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(4096, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(2, activation='softmax')
])

# %%
AlexNet.compile(loss='sparse_categorical_crossentropy', optimizer=tf.optimizers.SGD(lr=0.001), metrics=['accuracy'])
AlexNet.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 54, 54, 96)        34944
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
#  batch_normalization (BatchN  (None, 54, 54, 96)       384
#  ormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 96)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 26, 26, 256)       614656
#
#  batch_normalization_1 (Batc  (None, 26, 26, 256)      1024
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 256)      0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 12, 12, 384)       885120
#
#  batch_normalization_2 (Batc  (None, 12, 12, 384)      1536
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 384)       1327488
#
#  batch_normalization_3 (Batc  (None, 12, 12, 384)      1536
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 12, 12, 256)       884992
#
#  batch_normalization_4 (Batc  (None, 12, 12, 256)      1024
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 5, 5, 256)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 6400)              0
#
#  dense_1 (Dense)             (None, 4096)              26218496
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_2 (Dense)             (None, 4096)              16781312
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_3 (Dense)             (None, 2)                 8194
#
# =================================================================
# Total params: 46,760,706
# Trainable params: 46,757,954
# Non-trainable params: 2,752
# _________________________________________________________________

# %%
history_2=AlexNet.fit(train_data,
                      epochs=100,
                      
                      validation_data=valid_data,
                       callbacks=[callback]
                      )
# Out:
# Epoch 1/100
# 2536/2536 [==============================] - 188s 74ms/step - loss: 2.3161 - accuracy: 0.5627 - val_loss: 0.8833 - val_accuracy: 0.5100
# Epoch 2/100
# 2536/2536 [==============================] - 31s 12ms/step - loss: 0.8578 - accuracy: 0.5911 - val_loss: 0.6824 - val_accuracy: 0.6200
# Epoch 3/100
# 2536/2536 [==============================] - 31s 12ms/step - loss: 0.7165 - accuracy: 0.6203 - val_loss: 0.6909 - val_accuracy: 0.6300
# Epoch 4/100
# 2536/2536 [==============================] - 30s 12ms/step - loss: 0.6438 - accuracy: 0.6550 - val_loss: 0.7888 - val_accuracy: 0.5800
# Epoch 5/100
# 2536/2536 [==============================] - 30s 12ms/step - loss: 0.6114 - accuracy: 0.6857 - val_loss: 0.7273 - val_accuracy: 0.5400
# Epoch 6/100
# 2536/2536 [==============================] - 30s 12ms/step - loss: 0.5940 - accuracy: 0.6841 - val_loss: 0.6428 - val_accuracy: 0.6000
# Epoch 7/100
# 2536/2536 [==============================] - 30s 12ms/step - loss: 0.5461 - accuracy: 0.7185 - val_loss: 0.7094 - val_accuracy: 0.6400
# Epoch 8/100
# 2536/2536 [==============================] - 30s 12ms/step - loss: 0.5266 - accuracy: 0.7429 - val_loss: 0.6953 - val_accuracy: 0.6600
# Epoch 9/100
# 2536/2536 [==============================] - 30s 12ms/step - loss: 0.5016 - accuracy: 0.7563 - val_loss: 0.7614 - val_accuracy: 0.6400
# Epoch 10/100
# 2536/2536 [==============================] - 30s 12ms/step - loss: 0.4840 - accuracy: 0.7788 - val_loss: 0.6814 - val_accuracy: 0.6100
# Epoch 11/100
# 2536/2536 [==============================] - 30s 12ms/step - loss: 0.4669 - accuracy: 0.7685 - val_loss: 0.7967 - val_accuracy: 0.6200
# Epoch 12/100
# 2536/2536 [==============================] - 30s 12ms/step - loss: 0.4436 - accuracy: 0.7843 - val_loss: 0.7084 - val_accuracy: 0.6400
# Epoch 13/100
# 2536/2536 [==============================] - 30s 12ms/step - loss: 0.4156 - accuracy: 0.8021 - val_loss: 0.7996 - val_accuracy: 0.6100
# Epoch 14/100
# 2536/2536 [==============================] - 31s 12ms/step - loss: 0.4193 - accuracy: 0.8048 - val_loss: 0.9583 - val_accuracy: 0.5500
# Epoch 15/100
# 2536/2536 [==============================] - 30s 12ms/step - loss: 0.3908 - accuracy: 0.8229 - val_loss: 0.7780 - val_accuracy: 0.6700
# Epoch 16/100
# 2536/2536 [==============================] - 30s 12ms/step - loss: 0.3624 - accuracy: 0.8316 - val_loss: 0.9226 - val_accuracy: 0.6100
# Epoch 17/100
# 2536/2536 [==============================] - 30s 12ms/step - loss: 0.3489 - accuracy: 0.8340 - val_loss: 0.9882 - val_accuracy: 0.5700
# Epoch 18/100
# 2536/2536 [==============================] - 30s 12ms/step - loss: 0.2900 - accuracy: 0.8730 - val_loss: 1.1613 - val_accuracy: 0.6200
# Epoch 19/100
# 2536/2536 [==============================] - 30s 12ms/step - loss: 0.2687 - accuracy: 0.8817 - val_loss: 1.0214 - val_accuracy: 0.6500
# Epoch 20/100
# 2536/2536 [==============================] - 31s 12ms/step - loss: 0.2536 - accuracy: 0.8987 - val_loss: 1.0656 - val_accuracy: 0.6000
# Epoch 21/100
# 2536/2536 [==============================] - 31s 12ms/step - loss: 0.2351 - accuracy: 0.9002 - val_loss: 1.3098 - val_accuracy: 0.5600
# Epoch 22/100
# 2536/2536 [==============================] - 30s 12ms/step - loss: 0.2224 - accuracy: 0.9097 - val_loss: 1.0978 - val_accuracy: 0.5900
# Epoch 23/100
# 2536/2536 [==============================] - 30s 12ms/step - loss: 0.1757 - accuracy: 0.9345 - val_loss: 1.3206 - val_accuracy: 0.5800
# Epoch 24/100
# 2536/2536 [==============================] - 30s 12ms/step - loss: 0.1803 - accuracy: 0.9259 - val_loss: 1.5349 - val_accuracy: 0.6300
# Epoch 25/100
# 2536/2536 [==============================] - 30s 12ms/step - loss: 0.1703 - accuracy: 0.9302 - val_loss: 1.5291 - val_accuracy: 0.6500
# Epoch 26/100
# 2536/2536 [==============================] - 31s 12ms/step - loss: 0.1495 - accuracy: 0.9409 - val_loss: 1.2483 - val_accuracy: 0.5900
# Epoch 27/100
# 2536/2536 [==============================] - 30s 12ms/step - loss: 0.1150 - accuracy: 0.9614 - val_loss: 1.2843 - val_accuracy: 0.5900
# Epoch 28/100
# 2536/2536 [==============================] - 32s 13ms/step - loss: 0.1212 - accuracy: 0.9499 - val_loss: 1.7208 - val_accuracy: 0.5900
# Epoch 29/100
# 2536/2536 [==============================] - 30s 12ms/step - loss: 0.1163 - accuracy: 0.9558 - val_loss: 1.7465 - val_accuracy: 0.6300
# Epoch 30/100
# 2536/2536 [==============================] - 30s 12ms/step - loss: 0.0814 - accuracy: 0.9673 - val_loss: 2.2876 - val_accuracy: 0.5800
# Epoch 31/100
# 2536/2536 [==============================] - 31s 12ms/step - loss: 0.0673 - accuracy: 0.9748 - val_loss: 2.2578 - val_accuracy: 0.6100
# Epoch 32/100
# 2536/2536 [==============================] - 30s 12ms/step - loss: 0.0670 - accuracy: 0.9775 - val_loss: 2.2182 - val_accuracy: 0.5700
# Epoch 33/100
# 2536/2536 [==============================] - 30s 12ms/step - loss: 0.0381 - accuracy: 0.9886 - val_loss: 2.1842 - val_accuracy: 0.6600
# Epoch 34/100
# 2536/2536 [==============================] - 30s 12ms/step - loss: 0.0657 - accuracy: 0.9775 - val_loss: 1.9240 - val_accuracy: 0.6700
# Epoch 35/100
# 2536/2536 [==============================] - 30s 12ms/step - loss: 0.0926 - accuracy: 0.9673 - val_loss: 2.0791 - val_accuracy: 0.6200
