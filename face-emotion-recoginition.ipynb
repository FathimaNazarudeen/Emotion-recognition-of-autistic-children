# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
import tensorflow as tf
import keras
import cv2
import numpy as np # linear algebra
import pandas as pd

from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model
from tensorflow.keras import layers , models, optimizers

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import *

# %%
img_shape = 48
batch_size = 64
train_data_path = '../input/fer2013/train/'
test_data_path = '../input/fer2013/test/'

# %%
train_gen = ImageDataGenerator(
        rescale= 1 / 255,
        # Data Augmentation
        rotation_range=10,
        zoom_range= 0.2,
        width_shift_range= 0.1,
        height_shift_range= 0.1,
        fill_mode ="nearest"
    
    )

test_gen = ImageDataGenerator(rescale= 1 / 255 )

# %%
train_data = train_gen.flow_from_directory(
    train_data_path,
    class_mode="categorical",
    target_size=(img_shape,img_shape),
    color_mode='rgb', 
    shuffle=True,
    batch_size=batch_size,
    subset='training', 
)


test_data = test_gen.flow_from_directory(
    test_data_path,
    class_mode="categorical",
    target_size=(img_shape,img_shape),
    color_mode="rgb",
    shuffle=False,
    batch_size=batch_size,
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
def Create_CNN_Model():
    
    model = Sequential()
    
    #CNN1
    model.add(Conv2D(32, (3,3), activation='relu', input_shape=(img_shape, img_shape, 3)))
    model.add(BatchNormalization())
    model.add(Conv2D(64,(3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2), padding='same'))
    model.add(Dropout(0.25))
    
    #CNN2
    model.add(Conv2D(64, (3,3), activation='relu', ))
    model.add(BatchNormalization())
    model.add(Conv2D(128,(3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2), padding='same'))
    model.add(Dropout(0.25))
    
    #CNN3
    model.add(Conv2D(128, (3,3), activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(256,(3,3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2), padding='same'))
    model.add(Dropout(0.25))
    
    
    #Output
    model.add(Flatten())
    
    model.add(Dense(1024, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(512, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(256, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(128, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(64, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(32, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    model.add(Dense(7,activation='softmax'))
    
    
    return model

# %%
CNN_Model = Create_CNN_Model()

CNN_Model.summary()

CNN_Model.compile(optimizer="adam", loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# 2022-11-20 23:35:10.613217: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-20 23:35:10.614445: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-20 23:35:10.781094: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-20 23:35:10.782004: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-20 23:35:10.782821: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-20 23:35:10.783606: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-20 23:35:10.785071: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-20 23:35:11.042664: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-20 23:35:11.043533: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-20 23:35:11.044324: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-20 23:35:11.045069: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-20 23:35:11.045792: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-20 23:35:11.046512: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-20 23:35:13.998604: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-20 23:35:13.999809: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-20 23:35:14.000881: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-20 23:35:14.001935: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-20 23:35:14.002991: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-20 23:35:14.003906: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-11-20 23:35:14.007940: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-20 23:35:14.008854: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 46, 46, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 46, 46, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 46, 46, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 46, 46, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 23, 23, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 21, 21, 64)        36928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 21, 21, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 21, 21, 128)       73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 21, 21, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 11, 11, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 11, 11, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 9, 9, 128)         147584
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 9, 9, 128)         512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 9, 9, 256)         295168
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 9, 9, 256)         1024
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              6554624
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                2080
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 32)                128
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 7,837,895
# Trainable params: 7,832,519
# Non-trainable params: 5,376
# _________________________________________________________________

# %%
steps_per_epoch = train_data.n // train_data.batch_size
validation_steps = test_data.n // test_data.batch_size

# %%
CNN_history = CNN_Model.fit( train_data , 
                            validation_data= test_data ,
                            epochs=50, batch_size= batch_size,
                            
                             steps_per_epoch= steps_per_epoch, 
                            validation_steps=validation_steps
                           )
# Out:
# 2022-11-20 23:35:15.419626: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 2022-11-20 23:35:19.193295: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 448/448 [==============================] - 207s 439ms/step - loss: 2.0684 - accuracy: 0.2054 - val_loss: 1.8625 - val_accuracy: 0.2483
# Epoch 2/50
# 448/448 [==============================] - 61s 135ms/step - loss: 1.7846 - accuracy: 0.2749 - val_loss: 1.7178 - val_accuracy: 0.3124
# Epoch 3/50
# 448/448 [==============================] - 59s 132ms/step - loss: 1.6430 - accuracy: 0.3527 - val_loss: 1.6722 - val_accuracy: 0.3763
# Epoch 4/50
# 448/448 [==============================] - 59s 132ms/step - loss: 1.5085 - accuracy: 0.4143 - val_loss: 1.3714 - val_accuracy: 0.4715
# Epoch 5/50
# 448/448 [==============================] - 59s 132ms/step - loss: 1.4068 - accuracy: 0.4612 - val_loss: 1.2699 - val_accuracy: 0.5137
# Epoch 6/50
# 448/448 [==============================] - 59s 131ms/step - loss: 1.3499 - accuracy: 0.4914 - val_loss: 1.2403 - val_accuracy: 0.5264
# Epoch 7/50
# 448/448 [==============================] - 59s 132ms/step - loss: 1.3126 - accuracy: 0.5036 - val_loss: 1.3430 - val_accuracy: 0.5043
# Epoch 8/50
# 448/448 [==============================] - 59s 132ms/step - loss: 1.2704 - accuracy: 0.5241 - val_loss: 1.3280 - val_accuracy: 0.4932
# Epoch 9/50
# 448/448 [==============================] - 59s 132ms/step - loss: 1.2351 - accuracy: 0.5377 - val_loss: 1.3620 - val_accuracy: 0.4866
# Epoch 10/50
# 448/448 [==============================] - 59s 132ms/step - loss: 1.2161 - accuracy: 0.5464 - val_loss: 1.1702 - val_accuracy: 0.5566
# Epoch 11/50
# 448/448 [==============================] - 59s 131ms/step - loss: 1.1952 - accuracy: 0.5522 - val_loss: 1.2595 - val_accuracy: 0.5299
# Epoch 12/50
# 448/448 [==============================] - 59s 132ms/step - loss: 1.1701 - accuracy: 0.5639 - val_loss: 1.1931 - val_accuracy: 0.5343
# Epoch 13/50
# 448/448 [==============================] - 59s 132ms/step - loss: 1.1475 - accuracy: 0.5764 - val_loss: 1.2799 - val_accuracy: 0.5232
# Epoch 14/50
# 448/448 [==============================] - 59s 131ms/step - loss: 1.1362 - accuracy: 0.5818 - val_loss: 1.0648 - val_accuracy: 0.6034
# Epoch 15/50
# 448/448 [==============================] - 59s 131ms/step - loss: 1.1128 - accuracy: 0.5884 - val_loss: 1.0560 - val_accuracy: 0.6048
# Epoch 16/50
# 448/448 [==============================] - 59s 131ms/step - loss: 1.1035 - accuracy: 0.5931 - val_loss: 1.0548 - val_accuracy: 0.6066
# Epoch 17/50
# 448/448 [==============================] - 59s 131ms/step - loss: 1.0849 - accuracy: 0.5991 - val_loss: 1.0522 - val_accuracy: 0.6056
# Epoch 18/50
# 448/448 [==============================] - 59s 132ms/step - loss: 1.0631 - accuracy: 0.6089 - val_loss: 1.0757 - val_accuracy: 0.5961
# Epoch 19/50
# 448/448 [==============================] - 58s 130ms/step - loss: 1.0582 - accuracy: 0.6132 - val_loss: 1.0348 - val_accuracy: 0.6077
# Epoch 20/50
# 448/448 [==============================] - 58s 129ms/step - loss: 1.0443 - accuracy: 0.6172 - val_loss: 1.0620 - val_accuracy: 0.5907
# Epoch 21/50
# 448/448 [==============================] - 58s 130ms/step - loss: 1.0365 - accuracy: 0.6217 - val_loss: 0.9938 - val_accuracy: 0.6307
# Epoch 22/50
# 448/448 [==============================] - 59s 131ms/step - loss: 1.0269 - accuracy: 0.6245 - val_loss: 1.0618 - val_accuracy: 0.5972
# Epoch 23/50
# 448/448 [==============================] - 58s 130ms/step - loss: 1.0160 - accuracy: 0.6293 - val_loss: 0.9672 - val_accuracy: 0.6350
# Epoch 24/50
# 448/448 [==============================] - 58s 129ms/step - loss: 1.0108 - accuracy: 0.6294 - val_loss: 0.9922 - val_accuracy: 0.6286
# Epoch 25/50
# 448/448 [==============================] - 58s 130ms/step - loss: 0.9930 - accuracy: 0.6390 - val_loss: 1.0101 - val_accuracy: 0.6237
# Epoch 26/50
# 448/448 [==============================] - 61s 135ms/step - loss: 0.9782 - accuracy: 0.6443 - val_loss: 1.0332 - val_accuracy: 0.6183
# Epoch 27/50
# 448/448 [==============================] - 59s 132ms/step - loss: 0.9763 - accuracy: 0.6451 - val_loss: 0.9687 - val_accuracy: 0.6328
# Epoch 28/50
# 448/448 [==============================] - 59s 132ms/step - loss: 0.9624 - accuracy: 0.6499 - val_loss: 1.0173 - val_accuracy: 0.6235
# Epoch 29/50
# 448/448 [==============================] - 59s 131ms/step - loss: 0.9522 - accuracy: 0.6566 - val_loss: 0.9676 - val_accuracy: 0.6406
# Epoch 30/50
# 448/448 [==============================] - 58s 130ms/step - loss: 0.9475 - accuracy: 0.6588 - val_loss: 0.9640 - val_accuracy: 0.6403
# Epoch 31/50
# 448/448 [==============================] - 59s 132ms/step - loss: 0.9376 - accuracy: 0.6584 - val_loss: 0.9877 - val_accuracy: 0.6362
# Epoch 32/50
# 448/448 [==============================] - 59s 132ms/step - loss: 0.9270 - accuracy: 0.6645 - val_loss: 0.9662 - val_accuracy: 0.6429
# Epoch 33/50
# 448/448 [==============================] - 59s 131ms/step - loss: 0.9209 - accuracy: 0.6677 - val_loss: 0.9711 - val_accuracy: 0.6443
# Epoch 34/50
# 448/448 [==============================] - 59s 132ms/step - loss: 0.9100 - accuracy: 0.6706 - val_loss: 0.9699 - val_accuracy: 0.6437
# Epoch 35/50
# 448/448 [==============================] - 59s 131ms/step - loss: 0.8981 - accuracy: 0.6768 - val_loss: 0.9616 - val_accuracy: 0.6441
# Epoch 36/50
# 448/448 [==============================] - 64s 142ms/step - loss: 0.9016 - accuracy: 0.6720 - val_loss: 0.9398 - val_accuracy: 0.6568
# Epoch 37/50
# 448/448 [==============================] - 61s 135ms/step - loss: 0.8896 - accuracy: 0.6782 - val_loss: 0.9214 - val_accuracy: 0.6607
# Epoch 38/50
# 448/448 [==============================] - 60s 134ms/step - loss: 0.8721 - accuracy: 0.6879 - val_loss: 0.9663 - val_accuracy: 0.6399
# Epoch 39/50
# 448/448 [==============================] - 60s 133ms/step - loss: 0.8706 - accuracy: 0.6862 - val_loss: 0.9396 - val_accuracy: 0.6593
# Epoch 40/50
# 448/448 [==============================] - 64s 143ms/step - loss: 0.8635 - accuracy: 0.6888 - val_loss: 0.9572 - val_accuracy: 0.6479
# Epoch 41/50
# 448/448 [==============================] - 60s 134ms/step - loss: 0.8667 - accuracy: 0.6877 - val_loss: 1.0286 - val_accuracy: 0.6235
# Epoch 42/50
# 448/448 [==============================] - 60s 135ms/step - loss: 0.8762 - accuracy: 0.6862 - val_loss: 0.9117 - val_accuracy: 0.6699
# Epoch 43/50
# 448/448 [==============================] - 59s 132ms/step - loss: 0.8511 - accuracy: 0.6915 - val_loss: 1.0084 - val_accuracy: 0.6331
# Epoch 44/50
# 448/448 [==============================] - 59s 131ms/step - loss: 0.8317 - accuracy: 0.7029 - val_loss: 0.9447 - val_accuracy: 0.6590
# Epoch 47/50
# 448/448 [==============================] - 58s 130ms/step - loss: 0.8219 - accuracy: 0.7046 - val_loss: 0.9255 - val_accuracy: 0.6632
# Epoch 48/50
# 448/448 [==============================] - 59s 131ms/step - loss: 0.8195 - accuracy: 0.7087 - val_loss: 0.9382 - val_accuracy: 0.6617
# Epoch 49/50
# 448/448 [==============================] - 58s 130ms/step - loss: 0.8140 - accuracy: 0.7112 - val_loss: 0.9281 - val_accuracy: 0.6631
# Epoch 50/50
# 448/448 [==============================] - 58s 130ms/step - loss: 0.8162 - accuracy: 0.7084 - val_loss: 0.9002 - val_accuracy: 0.6749

# %%
CNN_Model.save("kaggle_model.h5")

# %%
CNN_Score = CNN_Model.evaluate(test_data)

print("    Test Loss: {:.5f}".format(CNN_Score[0]))
print("Test Accuracy: {:.2f}%".format(CNN_Score[1] * 100))
# Out:
# 113/113 [==============================] - 7s 57ms/step - loss: 0.8991 - accuracy: 0.6754
#     Test Loss: 0.89909
# Test Accuracy: 67.54%

# %%
def plot_curves(history):

    loss = history.history["loss"]
    val_loss = history.history["val_loss"]

    accuracy = history.history["accuracy"]
    val_accuracy = history.history["val_accuracy"]

    epochs = range(len(history.history["loss"]))

    plt.figure(figsize=(15,5))

    #plot loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, loss, label = "training_loss")
    plt.plot(epochs, val_loss, label = "val_loss")
    plt.title("Loss")
    plt.xlabel("epochs")
    plt.legend()

    #plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, accuracy, label = "training_accuracy")
    plt.plot(epochs, val_accuracy, label = "val_accuracy")
    plt.title("Accuracy")
    plt.xlabel("epochs")
    plt.legend()

# %%
import matplotlib.pyplot as plt
plot_curves(CNN_history)

# %%
CNN_Predictions = CNN_Model.predict(test_data)

# Choosing highest probalbilty class in every prediction 
CNN_Predictions = np.argmax(CNN_Predictions, axis=1)

# %%
test_data.class_indices
# Out:
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
import seaborn as sns 
from sklearn.metrics import confusion_matrix, classification_report

fig, ax= plt.subplots(figsize=(10,5))

cm=confusion_matrix(test_data.labels, CNN_Predictions)

sns.heatmap(cm, annot=True, fmt='g', ax=ax)

ax.set_xlabel('Predicted labels',fontsize=15, fontweight='bold')
ax.set_ylabel('True labels', fontsize=15, fontweight='bold')
ax.set_title('CNN Confusion Matrix', fontsize=20, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'CNN Confusion Matrix')

# %%
# Classification Report

report = classification_report(test_data.classes, CNN_Predictions)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.55      0.59       958
#            1       0.76      0.63      0.69       111
#            2       0.55      0.44      0.49      1024
#            3       0.88      0.87      0.87      1774
#            4       0.57      0.72      0.64      1233
#            5       0.56      0.54      0.55      1247
#            6       0.76      0.83      0.79       831
#
#     accuracy                           0.68      7178
#    macro avg       0.67      0.66      0.66      7178
# weighted avg       0.67      0.68      0.67      7178
